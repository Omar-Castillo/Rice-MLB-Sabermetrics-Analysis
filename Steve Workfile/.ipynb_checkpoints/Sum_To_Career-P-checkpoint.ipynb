# %%
import numpy as np
import pandas as pd

# %%
pitching3_df = pd.read_csv("db/pitching3.csv")

# %% [markdown]
# Summarize the pitching data into player data

# %%
pitching3_df = pitching3_df.groupby(["playerID"],as_index=False).sum()
pitching3_df.head(10)
# Out:
#     playerID  last season  season num  yearID    W    L    G   GS  IPouts  \
# 0  adamsba01        19250          55   19144  159  100  344  284    7100
# 1  alexape01        19290          55   19158  248  126  436  373   10027
# 2  blylebe01        19920          55   19745  148  128  353  350    7874
# 3  buehrma01        20150          55   20055  144  109  331  331    6660
# 4  bumgama01        18162          45   18126  110   83  251  251    4885
# 5  bunniji01        19710          55   19615  167  112  397  359    7957
# 6  caldwra02        19210          55   19155  126  114  300  246    6227
# 7  carltst01        19870          55   19715  165  123  358  353    7880
# 8  covelst01        19260          55   19205  192  128  392  337    8230
# 9  cuetojo01        18153          45   18112  117   81  272  272    5180
#
#       H   ...       ERA  CareerWS  decade  lastyear  numyears     wsPerYr  \
# 0  2088   ...     22.90      2430   19200     19260       190  127.894737
# 1  2902   ...     22.17      4760   19200     19300       200  238.000000
# 2  2335   ...     32.13      3390   19800     19920       220  154.090909
# 3  2334   ...     38.55      2080   20100     20150       160  130.000000
# 4  1423   ...     27.58       954   18090     18162        90   95.400000
# 5  2339   ...     31.19      2570   19600     19710       170  151.176471
# 6  1911   ...     33.50      1610   19200     19210       120  134.166667
# 7  2326   ...     31.21      3660   19800     19880       240  152.500000
# 8  2680   ...     28.47      2450   19200     19280       140  175.000000
# 9  1577   ...     34.89      1098   18090     18162        99   99.818182
#
#    pts_W  pts_K  pts_PCT  pts_ERA
# 0     20      0        2       12
# 1     89      8        6       24
# 2     14     13        0        5
# 3     12      0        0        0
# 4     12      7        0        4
# 5     26     12        4        5
# 6     12      0        0        8
# 7     28     12        4        7
# 8     46      0        2       12
# 9     14      2        2        4
#
# [10 rows x 23 columns]

# %%
pitching3_df.columns
# Out:
# Index(['playerID', 'last season', 'season num', 'yearID', 'W', 'L', 'G', 'GS',
#        'IPouts', 'H', 'ER', 'BB', 'SO', 'ERA', 'CareerWS', 'decade',
#        'lastyear', 'numyears', 'wsPerYr', 'pts_W', 'pts_K', 'pts_PCT',
#        'pts_ERA'],
#       dtype='object')

# %%
# no longer needed, and their sums would not make sense any way
del pitching3_df["yearID"]
del pitching3_df["last season"]
del pitching3_df["season num"]
del pitching3_df["CareerWS"]
del pitching3_df["decade"]
del pitching3_df["lastyear"]
del pitching3_df["numyears"]
del pitching3_df["wsPerYr"]
pitching3_df.head()
# Out:
#     playerID    W    L    G   GS  IPouts     H   ER   BB    SO    ERA  pts_W  \
# 0  adamsba01  159  100  344  284    7100  2088  608  341   890  22.90     20
# 1  alexape01  248  126  436  373   10027  2902  805  695  1774  22.17     89
# 2  blylebe01  148  128  353  350    7874  2335  841  711  2082  32.13     14
# 3  buehrma01  144  109  331  331    6660  2334  947  500  1250  38.55     12
# 4  bumgama01  110   83  251  251    4885  1423  550  382  1581  27.58     12
#
#    pts_K  pts_PCT  pts_ERA
# 0      0        2       12
# 1      8        6       24
# 2     13        0        5
# 3      0        0        0
# 4      7        0        4

# %%
# computed fields must be re-computed - their sums wouldn't make any sense
pitching3_df["ERA"]  = 9 * pitching3_df["ER"]/(pitching3_df["IPouts"]/3)
# I'd like to see what effect WHIP has, although I suspect it will be found to be highly correlated
pitching3_df["WHIP"] = (pitching3_df["H"]+pitching3_df["BB"])/(pitching3_df["IPouts"]/3)
pitching3_df["PCT"]  = pitching3_df["W"]/(pitching3_df["W"]+pitching3_df["L"])

# %%
pitching3_df.head(10)
# Out:
#     playerID    W    L    G   GS  IPouts     H   ER   BB    SO       ERA  \
# 0  adamsba01  159  100  344  284    7100  2088  608  341   890  2.312113
# 1  alexape01  248  126  436  373   10027  2902  805  695  1774  2.167647
# 2  blylebe01  148  128  353  350    7874  2335  841  711  2082  2.883795
# 3  buehrma01  144  109  331  331    6660  2334  947  500  1250  3.839189
# 4  bumgama01  110   83  251  251    4885  1423  550  382  1581  3.039918
# 5  bunniji01  167  112  397  359    7957  2339  908  667  2074  3.081061
# 6  caldwra02  126  114  300  246    6227  1911  714  680   913  3.095873
# 7  carltst01  165  123  358  353    7880  2326  907  935  2065  3.107741
# 8  covelst01  192  128  392  337    8230  2680  855  689   914  2.804982
# 9  cuetojo01  117   81  272  272    5180  1577  643  490  1454  3.351544
#
#    pts_W  pts_K  pts_PCT  pts_ERA      WHIP       PCT
# 0     20      0        2       12  1.026338  0.613900
# 1     89      8        6       24  1.076194  0.663102
# 2     14     13        0        5  1.160528  0.536232
# 3     12      0        0        0  1.276577  0.569170
# 4     12      7        0        4  1.108495  0.569948
# 5     26     12        4        5  1.133342  0.598566
# 6     12      0        0        8  1.248274  0.525000
# 7     28     12        4        7  1.241497  0.572917
# 8     46      0        2       12  1.228068  0.600000
# 9     14      2        2        4  1.197104  0.590909

# %% [markdown]
# At this point, introduce data to identify players as being in the Hall Of Fame or not

# %%
HOF_df = pd.read_csv("db/HallOfFame.csv")
HOF_df.head()
# Out:
#     playerID  yearID votedBy  ballots  needed  votes inducted category  \
# 0   cobbty01    1936   BBWAA    226.0   170.0  222.0        Y   Player
# 1   ruthba01    1936   BBWAA    226.0   170.0  215.0        Y   Player
# 2  wagneho01    1936   BBWAA    226.0   170.0  215.0        Y   Player
# 3  mathech01    1936   BBWAA    226.0   170.0  205.0        Y   Player
# 4  johnswa01    1936   BBWAA    226.0   170.0  189.0        Y   Player
#
#   needed_note
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
# unsuccessful votes are irrelevant for our purposes
HOF_subset1_df = HOF_df.loc[HOF_df["inducted"] == "Y", :]

# consider only those elected as players.  Some players were elected as managers.
HOF_subset2_df = HOF_subset1_df.loc[HOF_subset1_df["category"] == "Player", :]

# exclude any players elected from the Negro Leagues.  These are not likely to have relevant MLB statistics
HOF_subset3_df = HOF_subset2_df.loc[HOF_subset2_df["votedBy"] != "Negro League", :]


# discard unneeded columns
xyz = ["playerID","inducted"]
HOF_df = HOF_subset3_df[xyz]
HOF_df.head()
# Out:
#     playerID inducted
# 0   cobbty01        Y
# 1   ruthba01        Y
# 2  wagneho01        Y
# 3  mathech01        Y
# 4  johnswa01        Y

# %%
pitching3_df = pd.merge(pitching3_df, HOF_df, on="playerID", how="left")

# %%
pitching3_df.head(30)
# Out:
#      playerID    W    L    G   GS  IPouts     H    ER    BB    SO       ERA  \
# 0   adamsba01  159  100  344  284    7100  2088   608   341   890  2.312113
# 1   alexape01  248  126  436  373   10027  2902   805   695  1774  2.167647
# 2   blylebe01  148  128  353  350    7874  2335   841   711  2082  2.883795
# 3   buehrma01  144  109  331  331    6660  2334   947   500  1250  3.839189
# 4   bumgama01  110   83  251  251    4885  1423   550   382  1581  3.039918
# 5   bunniji01  167  112  397  359    7957  2339   908   667  2074  3.081061
# 6   caldwra02  126  114  300  246    6227  1911   714   680   913  3.095873
# 7   carltst01  165  123  358  353    7880  2326   907   935  2065  3.107741
# 8   covelst01  192  128  392  337    8230  2680   855   689   914  2.804982
# 9   cuetojo01  117   81  272  272    5180  1577   643   490  1454  3.351544
# 10  daussho01  160  140  376  302    7722  2537   907   806   960  3.171329
# 11   doakbi01  133  120  332  290    6513  2044   689   652   875  2.856287
# 12  drysddo01  164  118  397  344    7724  2264   846   681  1934  2.957276
# 13  earnsge01  127   93  319  249    5746  1981   933   809  1002  4.384093
# 14  faberre01  170  121  370  292    7476  2359   771   732  1004  2.784510
# 15  fellebo01  198  117  396  346    8385  2287   961  1351  2092  3.094454
# 16  fishera01  100   94  278  208    5267  1667   550   481   680  2.819442
# 17   fordwh01  158   63  317  276    6112  1711   628   821  1209  2.774215
# 18  gibsobo01  184  106  343  324    7963  2149   794   862  2276  2.692201
# 19  glavito02  151   95  322  322    6438  2013   799   710  1344  3.350885
# 20  gomezle01  178   89  330  295    6993  2116   832   979  1391  3.212355
# 21  greinza01  122   90  329  291    5597  1817   735   465  1682  3.545649
# 22  grimebu01  161  137  355  304    7860  2733  1010   814  1024  3.469466
# 23  grovele01  203   87  424  279    7531  2411   847   772  1566  3.036649
# 24  haineje01  153  119  346  294    6985  2490   935   644   742  3.614173
# 25  hallaro01  143   69  292  272    5895  1881   697   411  1438  3.192366
# 26  hamelco01  121   91  307  306    6041  1794   741   515  1922  3.311869
# 27  harenda01  136  112  331  329    6341  2054   870   423  1806  3.704463
# 28  harrisl01   95  135  349  228    5251  1963   827   630   644  4.252333
# 29  hendrcl01  144  116  360  257    7114  2123   698   697  1092  2.649143
#
#     pts_W  pts_K  pts_PCT  pts_ERA      WHIP       PCT inducted
# 0      20      0        2       12  1.026338  0.613900      NaN
# 1      89      8        6       24  1.076194  0.663102        Y
# 2      14     13        0        5  1.160528  0.536232        Y
# 3      12      0        0        0  1.276577  0.569170      NaN
# 4      12      7        0        4  1.108495  0.569948      NaN
# 5      26     12        4        5  1.133342  0.598566        Y
# 6      12      0        0        8  1.248274  0.525000      NaN
# 7      28     12        4        7  1.241497  0.572917        Y
# 8      46      0        2       12  1.228068  0.600000        Y
# 9      14      2        2        4  1.197104  0.590909      NaN
# 10     24      0        2        5  1.298757  0.533333      NaN
# 11     16      0        4        9  1.241824  0.525692      NaN
# 12     32     13        2        6  1.143837  0.581560        Y
# 13     24      0        4        0  1.456666  0.577273      NaN
# 14     36      0        0       10  1.240369  0.584192        Y
# 15     54     16        4        4  1.301610  0.628571        Y
# 16      4      0        2        4  1.223467  0.515464      NaN
# 17     26      2        8        4  1.242801  0.714932        Y
# 18     42     20        4        8  1.134371  0.634483        Y
# 19     22      0        4        4  1.268872  0.613821        Y
# 20     38      0        8        3  1.327756  0.666667        Y
# 21     10      8        6        3  1.223155  0.575472      NaN
# 22     32      0        0        3  1.353817  0.540268        Y
# 23     63      2       12        6  1.267959  0.700000        Y
# 24     24      0        4        2  1.346027  0.562500        Y
# 25     22      6        6        3  1.166412  0.674528      NaN
# 26      4      8        4        2  1.146664  0.570755      NaN
# 27      6      6        0        0  1.171897  0.548387      NaN
# 28      4      0        0        0  1.481432  0.413043      NaN
# 29     26      0        6       10  1.189204  0.553846      NaN

# %% [markdown]
# We will need to convert the "inducted" to 1s and 0s

# %%
HOF_member = []
for index, player in pitching3_df.iterrows():
    if player["inducted"] == "Y":
        HOF_member.append(1)
    else:
        HOF_member.append(0)

pitching3_df["HOF_member"] = HOF_member
pitching3_df.head(10)
# Out:
#     playerID    W    L    G   GS  IPouts     H   ER   BB    SO       ERA  \
# 0  adamsba01  159  100  344  284    7100  2088  608  341   890  2.312113
# 1  alexape01  248  126  436  373   10027  2902  805  695  1774  2.167647
# 2  blylebe01  148  128  353  350    7874  2335  841  711  2082  2.883795
# 3  buehrma01  144  109  331  331    6660  2334  947  500  1250  3.839189
# 4  bumgama01  110   83  251  251    4885  1423  550  382  1581  3.039918
# 5  bunniji01  167  112  397  359    7957  2339  908  667  2074  3.081061
# 6  caldwra02  126  114  300  246    6227  1911  714  680   913  3.095873
# 7  carltst01  165  123  358  353    7880  2326  907  935  2065  3.107741
# 8  covelst01  192  128  392  337    8230  2680  855  689   914  2.804982
# 9  cuetojo01  117   81  272  272    5180  1577  643  490  1454  3.351544
#
#    pts_W  pts_K  pts_PCT  pts_ERA      WHIP       PCT inducted  HOF_member
# 0     20      0        2       12  1.026338  0.613900      NaN           0
# 1     89      8        6       24  1.076194  0.663102        Y           1
# 2     14     13        0        5  1.160528  0.536232        Y           1
# 3     12      0        0        0  1.276577  0.569170      NaN           0
# 4     12      7        0        4  1.108495  0.569948      NaN           0
# 5     26     12        4        5  1.133342  0.598566        Y           1
# 6     12      0        0        8  1.248274  0.525000      NaN           0
# 7     28     12        4        7  1.241497  0.572917        Y           1
# 8     46      0        2       12  1.228068  0.600000        Y           1
# 9     14      2        2        4  1.197104  0.590909      NaN           0

# %%
pitching3_df.columns
# Out:
# Index(['playerID', 'W', 'L', 'G', 'GS', 'IPouts', 'H', 'ER', 'BB', 'SO', 'ERA',
#        'pts_W', 'pts_K', 'pts_PCT', 'pts_ERA', 'WHIP', 'PCT', 'inducted',
#        'HOF_member'],
#       dtype='object')

# %% [markdown]
# Columns with high correlation should not both be used.

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
# create a work dataframe that will make seeing correlations a little easier
work_df = pitching3_df[["G", "W", "SO", "PCT", "ERA", "WHIP", "pts_W", "pts_K", "pts_PCT", "pts_ERA"]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corr_matrix = work_df.corr()
corr_matrix[np.abs(corr_matrix) < .6] = 0      # masking lower correlations helps higher ones to stand out

plt.figure(figsize=(16,10))
sns.heatmap(corr_matrix, annot=True, cmap='YlGnBu')
plt.show()

# %% [markdown]
# Unsurprisingly, all representations of seasonal accomplishments (pts_x) have a high correlation with their corresponding career fields, just as they did with batting statistics.  So they can be discarded.
#
# That leaves us with six stats:  Games, Wins, Strikeouts, Winning Percent, Earned Run Average, and Walks/Hits per Inning Pitched. Two pairs are rather highly correlated:  ERA / WHIP, and W / G.  We proceed with caution from here, and perhaps consider later whether one should be eliminated.

# %% [markdown]
# -----
# With that, we can cut down again on the number of columns we need to keep.  With a change this big, we'll move to the next generation (batting4),

# %%
xyz = ["playerID","G", "W", "SO","PCT", "ERA","WHIP","HOF_member"]
pitching4_df = pitching3_df[xyz]
pitching4_df.head()
# Out:
#     playerID    G    W    SO  PCT  ERA  WHIP  HOF_member
# 0  adamsba01  344  159   890 0.61 2.31  1.03           0
# 1  alexape01  436  248  1774 0.66 2.17  1.08           1
# 2  blylebe01  353  148  2082 0.54 2.88  1.16           1
# 3  buehrma01  331  144  1250 0.57 3.84  1.28           0
# 4  bumgama01  251  110  1581 0.57 3.04  1.11           0

# %% [markdown]
# "lastyear" was polluted by being summed, but we still need it for one more thing.  Merge it back in from when it was last good, that being in pitching2.

# %%
pitching2_df = pd.read_csv("db/pitching2.csv")
pitching2_df = pitching2_df[["playerID","lastyear"]]
pitching2_df.drop_duplicates(inplace=True)
pitching2_df.head(10)
# Out:
#      playerID  lastyear
# 0   adamsba01      1926
# 19  aldrivi01      1928
# 28  alexape01      1930
# 48   alouma01      1965
# 49  avilaal01      2018
# 50  aybarer01      2017
# 51  bagbyji01      1923
# 60  bandosa01      1979
# 61   bellde01      2000
# 62  blylebe01      1992

# %%
pitching4_df = pd.merge(pitching4_df, pitching2_df, on="playerID", how="left")
pitching4_df.head(20)
# Out:
#      playerID    G    W    SO  PCT  ERA  WHIP  HOF_member  lastyear
# 0   adamsba01  344  159   890 0.61 2.31  1.03           0      1926
# 1   alexape01  436  248  1774 0.66 2.17  1.08           1      1930
# 2   blylebe01  353  148  2082 0.54 2.88  1.16           1      1992
# 3   buehrma01  331  144  1250 0.57 3.84  1.28           0      2015
# 4   bumgama01  251  110  1581 0.57 3.04  1.11           0      2018
# 5   bunniji01  397  167  2074 0.60 3.08  1.13           1      1971
# 6   caldwra02  300  126   913 0.53 3.10  1.25           0      1921
# 7   carltst01  358  165  2065 0.57 3.11  1.24           1      1988
# 8   covelst01  392  192   914 0.60 2.80  1.23           1      1928
# 9   cuetojo01  272  117  1454 0.59 3.35  1.20           0      2018
# 10  daussho01  376  160   960 0.53 3.17  1.30           0      1926
# 11   doakbi01  332  133   875 0.53 2.86  1.24           0      1929
# 12  drysddo01  397  164  1934 0.58 2.96  1.14           1      1969
# 13  earnsge01  319  127  1002 0.58 4.38  1.46           0      1936
# 14  faberre01  370  170  1004 0.58 2.78  1.24           1      1933
# 15  fellebo01  396  198  2092 0.63 3.09  1.30           1      1956
# 16  fishera01  278  100   680 0.52 2.82  1.22           0      1920
# 17   fordwh01  317  158  1209 0.71 2.77  1.24           1      1967
# 18  gibsobo01  343  184  2276 0.63 2.69  1.13           1      1975
# 19  glavito02  322  151  1344 0.61 3.35  1.27           1      2008

# %% [markdown]
# ------
# Next will be to split off more recent players.  These are still active and recent retirees, and can be used to make and test predictions.

# %%
pitching_recent_df = pitching4_df.loc[pitching4_df["lastyear"] > 2010, :]
pitching4_df       = pitching4_df.loc[pitching4_df["lastyear"] < 2011, :]

# %% [markdown]
# At this point, the data is ready to be processed into a logistic regression.  Drop lastyear.  Write out files without headers.

# %%
del pitching_recent_df["lastyear"]
pitching_recent_df.head()
# Out:
#      playerID    G    W    SO  PCT  ERA  WHIP  HOF_member
# 3   buehrma01  331  144  1250 0.57 3.84  1.28           0
# 4   bumgama01  251  110  1581 0.57 3.04  1.11           0
# 9   cuetojo01  272  117  1454 0.59 3.35  1.20           0
# 21  greinza01  329  122  1682 0.58 3.55  1.22           0
# 25  hallaro01  292  143  1438 0.67 3.19  1.17           0

# %%
del pitching4_df["lastyear"]
pitching4_df.head()
# Out:
#     playerID    G    W    SO  PCT  ERA  WHIP  HOF_member
# 0  adamsba01  344  159   890 0.61 2.31  1.03           0
# 1  alexape01  436  248  1774 0.66 2.17  1.08           1
# 2  blylebe01  353  148  2082 0.54 2.88  1.16           1
# 5  bunniji01  397  167  2074 0.60 3.08  1.13           1
# 6  caldwra02  300  126   913 0.53 3.10  1.25           0

# %%
pitching_recent_df.to_csv("db/pitching_recent.csv", index=False, header=True)

# %%
pitching4_df.to_csv("db/pitching4.csv", index=False, header=True)
