# %%
import plotly as py
# import cufflinks as cf
import pandas as pd

# %%
df = pd.read_csv('player_batter_combined.csv')
df.head()
# Out:
#    Season      data_type  playerid            Name       Team    G   PA  HR  \
# 0    2008  player_batter      4810    Brian McCann     Braves  145  573  23
# 1    2008  player_batter      1177   Albert Pujols  Cardinals  148  641  37
# 2    2008  player_batter      1679     Chase Utley   Phillies  159  707  33
# 3    2008  player_batter       548   Lance Berkman     Astros  159  665  29
# 4    2008  player_batter      4616  Russell Martin    Dodgers  155  650  13
#
#      R  RBI  ...  BABIP    AVG    OBP    SLG   wOBA   wRC+  BsR   Off   Def  \
# 0   68   87  ...  0.306  0.301  0.373  0.523  0.386  135.0 -4.8  20.5  50.1
# 1  100  116  ...  0.340  0.357  0.462  0.653  0.459  184.0 -0.2  67.7  -1.0
# 2  113  104  ...  0.301  0.292  0.380  0.535  0.389  134.0  7.2  37.6  21.8
# 3  114  106  ...  0.341  0.312  0.420  0.567  0.417  156.0  7.2  54.1   1.6
# 4   87   69  ...  0.309  0.280  0.385  0.396  0.350  112.0  1.4  11.2  44.8
#
#    WAR
# 0  8.9
# 1  8.7
# 2  8.2
# 3  7.7
# 4  7.6
#
# [5 rows x 24 columns]

# %%
# cf.set_config_file(offline=False, world_readable=True, theme='pearl')

df = pd.read_csv('player_batter_combined.csv')
# df2007 = df[df.year==2007]
# df.head(2)

df.iplot(kind='bubble', x='gdpPercap', y='lifeExp', size='pop', text='country',
             xTitle='GDP per Capita', yTitle='Life Expectancy',
             filename='cufflinks/simple-bubble-chart')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-4e5bbe9667e9> in <module>
#       6 # df.head(2)
#       7
# ----> 8 df.iplot(kind='bubble', x='gdpPercap', y='lifeExp', size='pop', text='country',
#       9              xTitle='GDP per Capita', yTitle='Life Expectancy',
#      10              filename='cufflinks/simple-bubble-chart')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'iplot'
